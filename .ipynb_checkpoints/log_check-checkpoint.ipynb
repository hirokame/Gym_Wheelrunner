# %%
import pandas as pd
pd.options.display.max_rows = 100

# %%
df = pd.read_csv("./log/progress.csv")

# %%
df
# Out:
#     time/time_elapsed  time/fps  rollout/ep_rew_mean  time/iterations  \
# 0                   0       849           -27.602319                1
# 1                   0       286            70.183784                2
# 2                   1       245           110.900267                3
# 3                   2       220           183.186778                4
# 4                   3       188           134.505198                5
# 5                   3       196           154.341483                6
# 6                   4       195           144.240369                7
# 7                   5       191           146.475876                8
# 8                   6       189           126.393513                9
# 9                   6       193            96.771095               10
# 10                  7       193           103.650226               11
# 11                  7       194            90.795121               12
# ...
